# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()
sns.set_theme()

# %% [markdown]
# ## Load the data

# %%
# Load the dataset
data = pd.read_csv('data/Salary_Data.csv')

data['Salary'] = data['Salary']/1000

data
# Out:
#     YearsExperience   Salary
# 0               1.1   39.343
# 1               1.3   46.205
# 2               1.5   37.731
# 3               2.0   43.525
# 4               2.2   39.891
# 5               2.9   56.642
# 6               3.0   60.150
# 7               3.2   54.445
# 8               3.2   64.445
# 9               3.7   57.189
# 10              3.9   63.218
# 11              4.0   55.794
# 12              4.0   56.957
# 13              4.1   57.081
# 14              4.5   61.111
# 15              4.9   67.938
# 16              5.1   66.029
# 17              5.3   83.088
# 18              5.9   81.363
# 19              6.0   93.940
# 20              6.8   91.738
# 21              7.1   98.273
# 22              7.9  101.302
# 23              8.2  113.812
# 24              8.7  109.431
# 25              9.0  105.582
# 26              9.5  116.969
# 27              9.6  112.635
# 28             10.3  122.391
# 29             10.5  121.872

# %%
# Plotting
plt.scatter(data['YearsExperience'], data['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary [1000$]')
plt.title('Years of Experience vs Salary')

plt.xlim([0,12])

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
features = data[['YearsExperience']]
target = data['Salary']

# %%
lr = LinearRegression()

# %%
lr.fit(features, target)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# np.float64(25.792200198668716)

# %%
lr.coef_
# Out:
# array([9.44996232])

# %%
predicted_values = lr.predict(data[['YearsExperience']])

# %%
predicted_values
# Out:
# array([ 36.18715875,  38.07715122,  39.96714368,  44.69212484,
#         46.58211731,  53.19709093,  54.14208716,  56.03207963,
#         56.03207963,  60.75706079,  62.64705325,  63.59204948,
#         63.59204948,  64.53704572,  68.31703065,  72.09701557,
#         73.98700804,  75.8770005 ,  81.5469779 ,  82.49197413,
#         90.05194398,  92.88693268, 100.44690254, 103.28189123,
#        108.0068724 , 110.84186109, 115.56684225, 116.51183848,
#        123.12681211, 125.01680457])

# %%
import numpy as np

new_values = np.array([[2], [2], [3]])

new_values
# Out:
# array([[2],
#        [2],
#        [3]])

# %%
lr.predict(new_values)
# Out:
# /Users/dalibor/anaconda3/envs/imgii_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44.69212484, 44.69212484, 54.14208716])

# %%
predicted_values

# %%
plt.scatter(data['YearsExperience'], data['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary [1000$]')
plt.title('Years of Experience vs Salary')

plt.plot(data['YearsExperience'], predicted_values, color='green')

# %%
plt.scatter(data['YearsExperience'], data['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary [1000$]')
plt.title('Years of Experience vs Salary')

plt.plot(
    data['YearsExperience'], 
    data['YearsExperience']*lr.coef_[0] + lr.intercept_, 
    color='green'
)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

# %%
intercept_rnd = 20
coef_rnd = 14.8

prediction_rnd =  data['YearsExperience']*coef_rnd + intercept_rnd

plt.scatter(data['YearsExperience'], data['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary [1000$]')
plt.title('Years of Experience vs Salary')

plt.plot(data['YearsExperience'], prediction_rnd, color='green')

# %% [markdown]
# ## Mean absolute error

# %%
mean_absolute_error(data['Salary'], prediction_rnd)
# Out:
# 23.302866666666674

# %%
mean_absolute_error(data['Salary'], predicted_values)
# Out:
# 4.644201289443536

# %% [markdown]
# ## Root mean squared error

# %%
root_mean_squared_error(data['Salary'], prediction_rnd)
# Out:
# 27.684250951277946

# %%
root_mean_squared_error(data['Salary'], predicted_values)
# Out:
# 5.59204360876066

# %% [markdown]
# ## R squared

# %%
r2_score(data['Salary'], prediction_rnd)
# Out:
# -0.05494635865803943

# %%
r2_score(data['Salary'], predicted_values)
# Out:
# 0.9569566641435086
